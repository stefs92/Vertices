# %%
import numpy as np
import vortexes as vd
import plotstuff as ps
import runsim as rs

# %% [markdown]
# Simulation for a Gaussian: vortex density is more or less uniform

# %%
rs.runsim(W = 0.5, L = 5.0, halo_size = 1.0)
# Out:
# v_phi before solving
# [[ 0.  0.  0.  0.]
#  [ 0.  1.  1.  0.]
#  [ 0.  2.  2.  0.]
#  [ 0.  0.  0.  0.]]
# quivers before solving
# Energy before solving:
# 634674.379088
# Energy after solving:
# 5.3832199974
# v_phi after first iteration
# [[ 0.          0.          0.          0.        ]
#  [ 0.         -0.87034264  0.33606837  0.        ]
#  [ 0.         -0.03244407  0.05359966  0.        ]
#  [ 0.          0.          0.          0.        ]]
# 3.67305911041
# v_phi
# [[  1.38777878e-17   2.08166817e-17  -2.08166817e-17   9.54097912e-18
#     1.38777878e-17   0.00000000e+00  -6.93889390e-18   2.60208521e-18]
#  [ -9.81307787e-18   5.51871881e-02   7.05516662e-03   9.62971547e-03
#     1.26849620e-02   1.59463777e-02  -2.31488067e-02   3.36189997e-02]
#  [ -2.77555756e-17   8.20126777e-02   1.05366234e-02   1.46989524e-02
#     1.88925862e-02   2.35690473e-02  -3.43554148e-02   5.53259121e-02]
#  [ -9.81307787e-18   9.06368739e-02   1.27379981e-02   1.65483565e-02
# ...

# %% [markdown]
# Now, simulation for r e^(- r^2):

# %%
rs.runsim(W = 0.5, L = 5.0, halo_size = 0.2, l = 10.0)
# Out:
# v_phi before solving
# [[ 0.  0.  0.  0.]
#  [ 0.  1.  1.  0.]
#  [ 0.  2.  2.  0.]
#  [ 0.  0.  0.  0.]]
# quivers before solving
# Energy before solving:
# 634654.039848
# Energy after solving:
# 4.03312135371e-06
# v_phi after first iteration
# [[ 0.          0.          0.          0.        ]
#  [ 0.         -0.87037693  0.33607686  0.        ]
#  [ 0.         -0.03241214  0.05359863  0.        ]
#  [ 0.          0.          0.          0.        ]]
# 2.80656696498e-06
# v_phi
# [[  0.00000000e+00  -1.38777878e-17   6.93889390e-18  -4.33680869e-18
#     0.00000000e+00   2.08166817e-17   6.93889390e-18   9.54097912e-18]
#  [  0.00000000e+00  -3.35462323e-01  -5.21962560e-01  -1.95957218e-01
#     1.97290011e-01   1.73126048e-01   4.90653893e-18   3.36209433e-02]
#  [  0.00000000e+00  -5.60120846e-01  -8.70376930e-01  -3.22478616e-01
#     3.36076864e-01   2.92970813e-01   0.00000000e+00   5.53285834e-02]
#  [  0.00000000e+00  -3.53219736e-01  -5.44881403e-01  -1.86915319e-01
# ...
